# %% [markdown]
# # MIMIC-IV Radiology Note Analysis

# %%
import pandas as pd
import os
import numpy as np

csv_path = os.path.expanduser("~/data/mimic/mimiciv-note/2.2/radiology.csv")
df = pd.read_csv(csv_path)
df
# Out:
#                 note_id  subject_id     hadm_id note_type  note_seq  \
# 0        10000032-RR-14    10000032  22595853.0        RR        14
# 1        10000032-RR-15    10000032  22595853.0        RR        15
# 2        10000032-RR-16    10000032  22595853.0        RR        16
# 3        10000032-RR-18    10000032         NaN        RR        18
# 4        10000032-RR-20    10000032         NaN        RR        20
# ...                 ...         ...         ...       ...       ...
# 2321350  19999987-RR-17    19999987  23865745.0        RR        17
# 2321351  19999987-RR-18    19999987  23865745.0        RR        18
# 2321352  19999987-RR-19    19999987  23865745.0        RR        19
# 2321353  19999987-RR-20    19999987  23865745.0        RR        20
# 2321354  19999987-RR-21    19999987  23865745.0        RR        21
#
#                    charttime            storetime  \
# 0        2180-05-06 21:19:00  2180-05-06 23:32:00
# ...

# %%
def print_random_notes(df, n=5):
    random_indices = np.random.choice(df.index, n, replace=False)
    for idx in random_indices:
        print(f"--- Note ID: {df.loc[idx, 'note_id']} | Note Type: {df.loc[idx, 'note_type']} ---")
        print(f"{df.loc[idx, 'text']}\n\n")

print_random_notes(df)
# Out:
# --- Note ID: 15647159-RR-40 | Note Type: RR ---
# EXAMINATION:  BILATERAL DIGITAL DIAGNOSTIC MAMMOGRAM INTERPRETED WITH CAD AND
# LEFT BREAST ULTRASOUND
#
# INDICATION:  ___ male with history of metastatic adenocarcinoma as
# well as right lower lobe squamous cell carcinoma now presents with left breast
# palpable abnormality.
#
# COMPARISON:  None.  Baseline.
#
# TECHNIQUE:  Bilateral CC, MLO, left lateral, left CC and lateral spot
# compression views were obtained.  Computer aided detection was utilized and
# assisted with interpretation.  Targeted ultrasound was performed.
#
# FINDINGS:
#
# There is bilateral retroglandular nodular tissue, left greater than right,
# consistent with gynecomastia. There is no dominant mass, grouped suspicious
# microcalcifications or architectural distortion.
#
# BREAST ULTRASOUND:  Targeted ultrasound of the left breast from ___ o'clock
# 0-3 cm from the nipple, corresponding to the area of clinical concern as
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2321355 entries, 0 to 2321354
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   note_id     object
#  1   subject_id  int64
#  2   hadm_id     float64
#  3   note_type   object
#  4   note_seq    int64
#  5   charttime   object
#  6   storetime   object
#  7   text        object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 141.7+ MB

# %%
df['note_id'].value_counts()
# Out:
# note_id
# 19999987-RR-21    1
# 10000032-RR-14    1
# 10000032-RR-15    1
# 10000032-RR-16    1
# 10000032-RR-18    1
#                  ..
# 10000032-RR-35    1
# 10000032-RR-33    1
# 10000032-RR-32    1
# 10000032-RR-31    1
# 10000032-RR-29    1
# Name: count, Length: 2321355, dtype: int64
